# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
GSE63060_path = "/content/drive/MyDrive/Colab Notebooks/Personal/brain_disease_prediction/GEO/Alzheimer/blood tissue/GSE63060_expression.csv"
GSE63061_path = "/content/drive/MyDrive/Colab Notebooks/Personal/brain_disease_prediction/GEO/Alzheimer/blood tissue/GSE63061_expression.csv"

# %%
GSE63060 = pd.read_csv(GSE63060_path)
GSE63061 = pd.read_csv(GSE63061_path)

# %%
GSE63060.rename(columns={'Unnamed: 0':'patient_id'}, inplace=True)
GSE63061.rename(columns={'Unnamed: 0':'patient_id'}, inplace=True)

# %%
GSE63060.set_index('patient_id', inplace=True)
GSE63061.set_index('patient_id', inplace=True)

# %%
GSE63061
# Out:
#                1-Dec     1-Mar     2-Mar     3-Mar     5-Mar     6-Mar  \
# patient_id
# GSM1539409  6.046115  6.268807  7.793198  6.247908  6.217792  7.715288
# GSM1539410  6.068269  6.332623  7.822572  6.253956  6.146553  7.815891
# GSM1539411  6.049894  6.451657  7.821084  6.299298  6.231308  8.063262
# GSM1539412  6.022627  6.204796  8.183803  6.242987  6.073113  8.299693
# GSM1539413  6.024455  6.410122  8.448412  6.185270  6.168115  8.330396
# ...              ...       ...       ...       ...       ...       ...
# GSM1539792  6.050681  6.393572  7.546375  6.252932  6.226305  8.170299
# GSM1539793  6.110553  6.376821  8.007593  6.263650  6.138989  8.021647
# GSM1539794  6.017178  6.375036  7.813062  6.132921  6.176351  8.116965
# GSM1539795  6.025379  6.421969  7.425039  6.145381  6.166644  8.217646
# GSM1539796  6.011890  6.387507  7.516485  6.347492  6.200841  7.912282
#
#                7-Mar     8-Mar     9-Mar      A1BG  ...    ZYG11A    ZYG11B  \
# patient_id                                          ...
# GSM1539409  7.880070  6.898175  6.097052  6.363700  ...  6.024313  8.223230
# GSM1539410  7.950036  6.631771  6.110334  6.038703  ...  6.044935  8.423643
# GSM1539411  8.578855  7.258313  6.028404  6.149995  ...  6.050358  8.126528
# GSM1539412  7.528975  7.545952  6.125845  6.364765  ...  6.024002  8.443437
# GSM1539413  8.040028  7.083462  6.071435  6.154938  ...  6.014700  8.657116
# ...              ...       ...       ...       ...  ...       ...       ...
# GSM1539792  7.806016  6.963304  6.062263  6.139319  ...  6.086113  8.659101
# GSM1539793  7.953865  6.968087  5.999827  6.192208  ...  6.022127  8.149314
# GSM1539794  8.569122  6.976714  6.016029  6.089414  ...  6.053900  8.218770
# GSM1539795  7.805071  6.389516  6.118710  6.207077  ...  6.056959  8.487030
# GSM1539796  8.373554  6.672958  6.031891  6.088177  ...  6.007510  8.143475
#
#                   ZYX     ZZEF1      ZZZ3  dJ222E13.2  dJ341D10.1     gm127  \
# patient_id
# GSM1539409   9.639303  7.686363  6.312076    6.051220    6.236891  6.114106
# GSM1539410  10.255327  7.729719  6.234654    6.083923    6.398889  6.144168
# GSM1539411   9.643614  7.526946  6.441426    6.059549    6.322824  6.043692
# GSM1539412   9.966027  7.485560  6.167969    6.079597    6.177225  6.192038
# GSM1539413   9.640727  7.288133  6.422155    6.029469    6.324525  6.072912
# ...               ...       ...       ...         ...         ...       ...
# GSM1539792  10.350903  7.713113  6.271670    6.104885    6.656707  6.005648
# GSM1539793   9.762687  7.363716  6.354014    6.010161    6.407741  6.259958
# GSM1539794   9.624390  7.468304  6.346038    6.088197    6.388553  6.107970
# GSM1539795   9.814661  7.599343  6.411567    6.161716    6.438040  6.038780
# GSM1539796   9.433504  7.348540  6.446232    6.277709    6.543384  6.135045
#
#             psiTPTE22  status
# patient_id
# GSM1539409   6.017242     MCI
# GSM1539410   6.022783     MCI
# GSM1539411   6.096135     MCI
# GSM1539412   6.032421     MCI
# GSM1539413   6.056553     MCI
# ...               ...     ...
# GSM1539792   6.031678     MCI
# GSM1539793   6.103267     MCI
# GSM1539794   6.044537      AD
# GSM1539795   6.023027     CTL
# GSM1539796   6.039413     CTL
#
# [388 rows x 22337 columns]

# %%
print(len(GSE63060.columns))
print(len(GSE63061.columns))
# Out:
# 21697
# 22337

# %%
common_genes = GSE63060.columns.intersection(GSE63061.columns)

print("Common genes:", len(common_genes))
# Out:
# Common genes: 17154

# %%
GSE63061 = GSE63061[
    GSE63061["status"].isin(["AD", "MCI", "CTL"])
]

# Optional check
print(GSE63061["status"].value_counts())
print(GSE63061.shape)
# Out:
# status
# AD     139
# CTL    134
# MCI    109
# Name: count, dtype: int64
# (382, 22337)

# %%
GSE63060_common = GSE63060[common_genes]
GSE63061_common = GSE63061[common_genes]

# %%
merged_df = pd.concat(
    [GSE63060_common, GSE63061_common],
    axis=0
)

print(merged_df.shape)
# Out:
# (711, 17154)

# %%
merged_df
# Out:
#                 A1BG      A1CF     A26C3     A2BP1    A4GALT     A4GNT  \
# patient_id
# GSM1539080  7.600951  7.497117  7.476685  7.463816  7.476840  7.499282
# GSM1539081  7.672496  7.463011  7.651896  7.570863  7.445267  7.656974
# GSM1539082  7.538046  7.475873  7.461754  7.484247  7.314818  7.530972
# GSM1539083  7.577860  7.503082  7.488248  7.508958  7.486045  7.542443
# GSM1539084  7.678150  7.417203  7.481259  7.443698  7.428502  7.436986
# ...              ...       ...       ...       ...       ...       ...
# GSM1539792  6.139319  6.020684  6.065013  6.040905  6.018924  6.014391
# GSM1539793  6.192208  6.037401  6.073189  6.018387  6.011448  6.220108
# GSM1539794  6.089414  6.030420  6.073272  6.032869  6.009287  6.116415
# GSM1539795  6.207077  6.132552  6.048929  6.042658  6.013017  6.166866
# GSM1539796  6.088177  6.050763  6.087853  6.082210  6.018795  6.052033
#
#                 AAA1      AAAS      AACS     AACSL  ...    ZYG11A     ZYG11B  \
# patient_id                                          ...
# GSM1539080  7.638083  7.585404  8.148446  7.594694  ...  7.462498  10.618034
# GSM1539081  7.460855  7.612667  8.315475  7.492516  ...  7.472825  11.289126
# GSM1539082  7.445645  7.756228  7.912023  7.630822  ...  7.435084  11.068854
# GSM1539083  7.525906  7.984069  8.064728  7.487097  ...  7.377990  10.527572
# GSM1539084  7.411262  7.761655  7.977451  7.517720  ...  7.453386  10.833655
# ...              ...       ...       ...       ...  ...       ...        ...
# GSM1539792  6.112325  6.159050  6.191944  6.325955  ...  6.086113   8.659101
# GSM1539793  6.050225  6.081145  6.123798  6.240833  ...  6.022127   8.149314
# GSM1539794  6.056126  6.076175  6.255484  6.174056  ...  6.053900   8.218770
# GSM1539795  6.121869  6.026046  6.162781  6.187777  ...  6.056959   8.487030
# GSM1539796  6.085287  6.027978  6.151224  6.089731  ...  6.007510   8.143475
#
#                   ZYX     ZZEF1      ZZZ3  dJ222E13.2  dJ341D10.1     gm127  \
# patient_id
# GSM1539080  11.736463  8.561519  7.525411    7.738314    7.786112  7.466882
# GSM1539081  11.930612  8.697649  7.666053    7.602051    7.707824  7.498424
# GSM1539082  11.626505  8.889266  7.771253    7.775860    7.764043  7.415565
# GSM1539083  11.954639  8.665815  7.696854    8.114773    7.459060  7.608580
# GSM1539084  11.895018  8.785981  7.647086    7.705824    7.563035  7.484933
# ...               ...       ...       ...         ...         ...       ...
# GSM1539792  10.350903  7.713113  6.271670    6.104885    6.656707  6.005648
# GSM1539793   9.762687  7.363716  6.354014    6.010161    6.407741  6.259958
# GSM1539794   9.624390  7.468304  6.346038    6.088197    6.388553  6.107970
# GSM1539795   9.814661  7.599343  6.411567    6.161716    6.438040  6.038780
# GSM1539796   9.433504  7.348540  6.446232    6.277709    6.543384  6.135045
#
#             psiTPTE22  status
# patient_id
# GSM1539080   7.499674     MCI
# GSM1539081   7.648523     MCI
# GSM1539082   7.505945     MCI
# GSM1539083   7.534026     MCI
# GSM1539084   7.564126     MCI
# ...               ...     ...
# GSM1539792   6.031678     MCI
# GSM1539793   6.103267     MCI
# GSM1539794   6.044537      AD
# GSM1539795   6.023027     CTL
# GSM1539796   6.039413     CTL
#
# [711 rows x 17154 columns]

# %%
merged_df["status"].value_counts()
# Out:
# status
# AD     284
# CTL    238
# MCI    189
# Name: count, dtype: int64

# %% [markdown]
# ### LOG NORMALIZATION

# %%
X = merged_df.drop(columns=["status"])
y = merged_df["status"]


X_log = np.log2(X + 1)

# %% [markdown]
# ### VARIANCE FILTERING

# %%
gene_variance = merged_df.drop(columns=["status"]).var()

plt.figure(figsize=(8,5))
plt.hist(gene_variance, bins=100)
plt.title("Gene Variance Distribution")
plt.xlabel("Variance")
plt.ylabel("Gene Count")
plt.show()

# %%
variance = X_log.var()

threshold = variance.quantile(0.75)

selected_genes = variance[variance > threshold].index

X_filtered = X_log[selected_genes]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

y_encoded = le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_filtered,
    y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ### ANOVA FEATURE SELECTION

# %%
from sklearn.feature_selection import SelectKBest, f_classif

anova_selector = SelectKBest(score_func=f_classif, k=1000)

X_anova = anova_selector.fit_transform(
    X_train,
    y_train
)

# %%
X_anova.shape
# Out:
# (568, 1000)

# %% [markdown]
# ### MUTUAL INFORMATION

# %%
from sklearn.feature_selection import mutual_info_classif

mi_scores = mutual_info_classif(
    X_train,
    y_train
)

mi_df = pd.DataFrame({
    "Gene": X_filtered.columns,
    "MI": mi_scores
}).sort_values("MI", ascending=False)

# %%
top_genes = mi_df["Gene"].head(1000)

X_train_mi = X_train[top_genes]
X_test_mi = X_test[top_genes]

# %%
mi_df
# Out:
#            Gene        MI
# 4045      UQCRB  0.145165
# 802       COX17  0.138499
# 805       COX6C  0.132642
# 2086  LOC646200  0.128116
# 604      CCDC53  0.123929
# ...         ...       ...
# 2236  LOC652624  0.000000
# 731       CLCF1  0.000000
# 732       CLCN1  0.000000
# 2244  LOC652805  0.000000
# 461    C21orf67  0.000000
#
# [4288 rows x 2 columns]

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=50)

X_train_pca = pca.fit_transform(X_train)

# %%
X_test_pca = pca.transform(X_test)

# %% [markdown]
# ### SVD

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=50)

X_train_svd = svd.fit_transform(X_train)

X_test_svd = svd.transform(X_test)

# %% [markdown]
# ### DEEP AUTOENCODER

# %%
from tensorflow.keras import layers, Model
from tensorflow import keras
import tensorflow as tf

input_dim = X_train.shape[1]

inputs = layers.Input(shape=(input_dim,))

x = layers.Dense(2048, activation='relu')(inputs)
x = layers.Dropout(0.3)(x)

x = layers.Dense(512, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)

latent = layers.Dense(32, activation='relu', name="latent")(x)

x = layers.Dense(128, activation='relu')(latent)
x = layers.Dense(512, activation='relu')(x)

outputs = layers.Dense(input_dim, activation='linear')(x)

autoencoder = Model(inputs, outputs)
encoder = Model(inputs, latent)

# %%
autoencoder.compile(optimizer='adam', loss='mse')

model = autoencoder.fit(
    X_train,
    X_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - loss: 2.6970 - val_loss: 0.3212
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 244ms/step - loss: 0.1867 - val_loss: 0.0384
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 0.0654 - val_loss: 0.0589
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 0.0428 - val_loss: 0.0103
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 325ms/step - loss: 0.0329 - val_loss: 0.0803
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 197ms/step - loss: 0.0366 - val_loss: 0.0022
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - loss: 0.0577 - val_loss: 0.0172
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step - loss: 0.0452 - val_loss: 0.0543
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 296ms/step - loss: 0.0319 - val_loss: 0.0210
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 187ms/step - loss: 0.0331 - val_loss: 0.1423
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 184ms/step - loss: 0.0343 - val_loss: 0.0796
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 186ms/step - loss: 0.0263 - val_loss: 0.0794
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - loss: 0.0203 - val_loss: 0.1211
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 188ms/step - loss: 0.0254 - val_loss: 0.0391
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - loss: 0.0254 - val_loss: 0.0034
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - loss: 0.0278 - val_loss: 0.0159
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step - loss: 0.0273 - val_loss: 0.0852
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 0.0290 - val_loss: 0.0396
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - loss: 0.0297 - val_loss: 0.0421
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 0.0332 - val_loss: 0.0022
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.0474 - val_loss: 0.1420
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 198ms/step - loss: 0.0414 - val_loss: 0.0025
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - loss: 0.0274 - val_loss: 0.1279
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - loss: 0.0400 - val_loss: 0.0784
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 182ms/step - loss: 0.0251 - val_loss: 0.0202
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - loss: 0.0270 - val_loss: 0.1185
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - loss: 0.0356 - val_loss: 0.0022
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - loss: 0.0282 - val_loss: 0.0725
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - loss: 0.0289 - val_loss: 0.0054
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0186 - val_loss: 0.0442
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 232ms/step - loss: 0.0213 - val_loss: 0.0292
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - loss: 0.0229 - val_loss: 0.0688
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - loss: 0.0227 - val_loss: 0.1172
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - loss: 0.0219 - val_loss: 0.0206
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - loss: 0.0240 - val_loss: 0.0163
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 0.0296 - val_loss: 0.0600
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 0.0230 - val_loss: 0.1121
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - loss: 0.0293 - val_loss: 0.0379
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - loss: 0.0272 - val_loss: 0.1283
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - loss: 0.0211 - val_loss: 0.0153
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - loss: 0.0281 - val_loss: 0.0065
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0301 - val_loss: 0.0405
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 188ms/step - loss: 0.0275 - val_loss: 0.0252
# Epoch 44/50
#  1/15 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step - loss: 0.0210

# %%
X_train_ae = encoder.predict(X_train)
X_test_ae = encoder.predict(X_test)

# %%
len(X_test_ae)

# %% [markdown]
# # 1. SVM Model

# %%
from sklearn.svm import SVC
import numpy as np

model_svm = SVC(
    kernel="rbf",
    probability=True,
    C=1.0,
    gamma="scale",
    decision_function_shape="ovr"
)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np

def model_report(name, y_test, y_pred):
    print("\n" + "="*60)
    print(f"📊 MODEL REPORT: {name}")
    print("="*60)

    print("\n🔹 Accuracy:")
    print(accuracy_score(y_test, y_pred))

    print("\n🔹 Classification Report:")
    print(classification_report(y_test, y_pred))

    print("\n🔹 Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))

# %%
model_svm.fit(X_train_pca, y_train)
# Out:
# SVC(probability=True)

# %%
y_val_pred = model_svm.predict(X_test_pca)

model_report("PCA + MLP", y_test, y_val_pred)
# Out:
# ============================================================
# 📊 MODEL REPORT: PCA + MLP
# ============================================================
#
# 🔹 Accuracy:
# 0.46153846153846156
#
# 🔹 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.89      0.58        57
#            1       0.60      0.31      0.41        48
#            2       0.00      0.00      0.00        38
#
#     accuracy                           0.46       143
#    macro avg       0.34      0.40      0.33       143
# weighted avg       0.37      0.46      0.37       143
#
#
# 🔹 Confusion Matrix:
# [[51  6  0]
#  [33 15  0]
#  [34  4  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt

# probabilities
y_proba = model_svm.predict_proba(X_test_pca)

# classes
classes = np.unique(y_test)
y_test_bin = label_binarize(y_test, classes=classes)

fpr = {}
tpr = {}
roc_auc = {}

for i in range(len(classes)):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# plot
plt.figure(figsize=(8,6))

colors = plt.cm.tab10(np.linspace(0, 1, len(classes)))

for i in range(len(classes)):
    plt.plot(
        fpr[i],
        tpr[i],
        color=colors[i],
        lw=2,
        label=f"Class {classes[i]} (AUC = {roc_auc[i]:.3f})"
    )

plt.plot([0, 1], [0, 1], "k--", lw=2)

plt.title("ROC Curve - SVM + PCA")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.grid()

plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# predictions
y_pred = model_svm.predict(X_test_pca)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(7,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    linewidths=0.5
)

plt.title("Confusion Matrix - SVM + PCA")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()

# %%
model_svm.fit(X_train_ae, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred_ae = model_svm.predict(X_test_ae)
y_proba_ae = model_svm.predict_proba(X_test_ae)

model_report("AE + MLP", y_test, y_pred_ae)
# Out:
# ============================================================
# 📊 MODEL REPORT: AE + MLP
# ============================================================
#
# 🔹 Accuracy:
# 0.3986013986013986
#
# 🔹 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57        57
#            1       0.00      0.00      0.00        48
#            2       0.00      0.00      0.00        38
#
#     accuracy                           0.40       143
#    macro avg       0.13      0.33      0.19       143
# weighted avg       0.16      0.40      0.23       143
#
#
# 🔹 Confusion Matrix:
# [[57  0  0]
#  [48  0  0]
#  [38  0  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
model_svm.fit(X_train_svd, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred_svd = model_svm.predict(X_test_svd)
y_proba_svd = model_svm.predict_proba(X_test_svd)

model_report("AE + MLP", y_test, y_pred_ae)
# Out:
# ============================================================
# 📊 MODEL REPORT: AE + MLP
# ============================================================
#
# 🔹 Accuracy:
# 0.3986013986013986
#
# 🔹 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57        57
#            1       0.00      0.00      0.00        48
#            2       0.00      0.00      0.00        38
#
#     accuracy                           0.40       143
#    macro avg       0.13      0.33      0.19       143
# weighted avg       0.16      0.40      0.23       143
#
#
# 🔹 Confusion Matrix:
# [[57  0  0]
#  [48  0  0]
#  [38  0  0]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
history_mi = model_xgb.fit(
    X_train_mi,
    y_train,
    eval_set=[(X_test_mi, y_test)],
    verbose=True
)
# Out:
# [0]	validation_0-mlogloss:1.07507
# [1]	validation_0-mlogloss:1.06483
# [2]	validation_0-mlogloss:1.05617
# [3]	validation_0-mlogloss:1.04443
# [4]	validation_0-mlogloss:1.03543
# [5]	validation_0-mlogloss:1.02562
# [6]	validation_0-mlogloss:1.01734
# [7]	validation_0-mlogloss:1.00946
# [8]	validation_0-mlogloss:1.00263
# [9]	validation_0-mlogloss:0.99707
# [10]	validation_0-mlogloss:0.99132
# [11]	validation_0-mlogloss:0.98838
# [12]	validation_0-mlogloss:0.98589
# [13]	validation_0-mlogloss:0.98202
# [14]	validation_0-mlogloss:0.98187
# [15]	validation_0-mlogloss:0.97435
# [16]	validation_0-mlogloss:0.96842
# [17]	validation_0-mlogloss:0.96419
# [18]	validation_0-mlogloss:0.95570
# [19]	validation_0-mlogloss:0.95248
# [20]	validation_0-mlogloss:0.95021
# [21]	validation_0-mlogloss:0.94352
# [22]	validation_0-mlogloss:0.94122
# [23]	validation_0-mlogloss:0.93451
# [24]	validation_0-mlogloss:0.93071
# [25]	validation_0-mlogloss:0.92942
# [26]	validation_0-mlogloss:0.92600
# [27]	validation_0-mlogloss:0.92521
# [28]	validation_0-mlogloss:0.92135
# [29]	validation_0-mlogloss:0.92089
# [30]	validation_0-mlogloss:0.91776
# [31]	validation_0-mlogloss:0.91719
# [32]	validation_0-mlogloss:0.91426
# [33]	validation_0-mlogloss:0.91078
# [34]	validation_0-mlogloss:0.90581
# [35]	validation_0-mlogloss:0.90385
# [36]	validation_0-mlogloss:0.90288
# [37]	validation_0-mlogloss:0.90087
# [38]	validation_0-mlogloss:0.90001
# [39]	validation_0-mlogloss:0.89744
# [40]	validation_0-mlogloss:0.89636
# [41]	validation_0-mlogloss:0.89384
# [42]	validation_0-mlogloss:0.89308
# [43]	validation_0-mlogloss:0.89138
# [44]	validation_0-mlogloss:0.88918
# [45]	validation_0-mlogloss:0.88586
# [46]	validation_0-mlogloss:0.88388
# [47]	validation_0-mlogloss:0.88355
# [48]	validation_0-mlogloss:0.88210
# [49]	validation_0-mlogloss:0.88177
# [50]	validation_0-mlogloss:0.88068
# [51]	validation_0-mlogloss:0.88067
# [52]	validation_0-mlogloss:0.87827
# [53]	validation_0-mlogloss:0.87615
# [54]	validation_0-mlogloss:0.87551
# [55]	validation_0-mlogloss:0.87627
# [56]	validation_0-mlogloss:0.87469
# [57]	validation_0-mlogloss:0.87390
# [58]	validation_0-mlogloss:0.87359
# [59]	validation_0-mlogloss:0.87299
# [60]	validation_0-mlogloss:0.87336
# [61]	validation_0-mlogloss:0.87292
# [62]	validation_0-mlogloss:0.87403
# [63]	validation_0-mlogloss:0.87316
# [64]	validation_0-mlogloss:0.87190
# [65]	validation_0-mlogloss:0.87075
# [66]	validation_0-mlogloss:0.87028
# [67]	validation_0-mlogloss:0.87067
# [68]	validation_0-mlogloss:0.87014
# [69]	validation_0-mlogloss:0.87035
# [70]	validation_0-mlogloss:0.87040
# [71]	validation_0-mlogloss:0.86960
# [72]	validation_0-mlogloss:0.86933
# [73]	validation_0-mlogloss:0.86739
# [74]	validation_0-mlogloss:0.86701
# [75]	validation_0-mlogloss:0.86564
# [76]	validation_0-mlogloss:0.86647
# [77]	validation_0-mlogloss:0.86448
# [78]	validation_0-mlogloss:0.86410
# [79]	validation_0-mlogloss:0.86564
# [80]	validation_0-mlogloss:0.86387
# [81]	validation_0-mlogloss:0.86391
# [82]	validation_0-mlogloss:0.86217
# [83]	validation_0-mlogloss:0.86210
# [84]	validation_0-mlogloss:0.86169
# [85]	validation_0-mlogloss:0.86343
# [86]	validation_0-mlogloss:0.86318
# [87]	validation_0-mlogloss:0.86389
# [88]	validation_0-mlogloss:0.86260
# [89]	validation_0-mlogloss:0.86177
# [90]	validation_0-mlogloss:0.86213
# [91]	validation_0-mlogloss:0.86369
# [92]	validation_0-mlogloss:0.86406
# [93]	validation_0-mlogloss:0.86431
# [94]	validation_0-mlogloss:0.86460
# [95]	validation_0-mlogloss:0.86453
# [96]	validation_0-mlogloss:0.86263
# [97]	validation_0-mlogloss:0.86276
# [98]	validation_0-mlogloss:0.86070
# [99]	validation_0-mlogloss:0.86074
# [100]	validation_0-mlogloss:0.86201
# [101]	validation_0-mlogloss:0.86145
# [102]	validation_0-mlogloss:0.86026
# [103]	validation_0-mlogloss:0.86075
# [104]	validation_0-mlogloss:0.86216
# [105]	validation_0-mlogloss:0.86172
# [106]	validation_0-mlogloss:0.86290
# [107]	validation_0-mlogloss:0.86395
# [108]	validation_0-mlogloss:0.86452
# [109]	validation_0-mlogloss:0.86380
# [110]	validation_0-mlogloss:0.86388
# [111]	validation_0-mlogloss:0.86370
# [112]	validation_0-mlogloss:0.86285
# [113]	validation_0-mlogloss:0.86383
# [114]	validation_0-mlogloss:0.86394
# [115]	validation_0-mlogloss:0.86486
# [116]	validation_0-mlogloss:0.86483
# [117]	validation_0-mlogloss:0.86653
# [118]	validation_0-mlogloss:0.86639
# [119]	validation_0-mlogloss:0.86567
# [120]	validation_0-mlogloss:0.86596
# [121]	validation_0-mlogloss:0.86627
# [122]	validation_0-mlogloss:0.86663
# [123]	validation_0-mlogloss:0.86710
# [124]	validation_0-mlogloss:0.86743
# [125]	validation_0-mlogloss:0.86663
# [126]	validation_0-mlogloss:0.86777
# [127]	validation_0-mlogloss:0.86643
# [128]	validation_0-mlogloss:0.86692
# [129]	validation_0-mlogloss:0.86685
# [130]	validation_0-mlogloss:0.86672
# [131]	validation_0-mlogloss:0.86614
# [132]	validation_0-mlogloss:0.86533
# [133]	validation_0-mlogloss:0.86627
# [134]	validation_0-mlogloss:0.86537
# [135]	validation_0-mlogloss:0.86510
# [136]	validation_0-mlogloss:0.86500
# [137]	validation_0-mlogloss:0.86503
# [138]	validation_0-mlogloss:0.86565
# [139]	validation_0-mlogloss:0.86608
# [140]	validation_0-mlogloss:0.86567
# [141]	validation_0-mlogloss:0.86622
# [142]	validation_0-mlogloss:0.86704
# [143]	validation_0-mlogloss:0.86697
# [144]	validation_0-mlogloss:0.86694
# [145]	validation_0-mlogloss:0.86613
# [146]	validation_0-mlogloss:0.86669
# [147]	validation_0-mlogloss:0.86738
# [148]	validation_0-mlogloss:0.86791
# [149]	validation_0-mlogloss:0.86637
# [150]	validation_0-mlogloss:0.86611
# [151]	validation_0-mlogloss:0.86606
# [152]	validation_0-mlogloss:0.86565
# [153]	validation_0-mlogloss:0.86618
# [154]	validation_0-mlogloss:0.86556
# [155]	validation_0-mlogloss:0.86544
# [156]	validation_0-mlogloss:0.86503
# [157]	validation_0-mlogloss:0.86573
# [158]	validation_0-mlogloss:0.86628
# [159]	validation_0-mlogloss:0.86693
# [160]	validation_0-mlogloss:0.86690
# [161]	validation_0-mlogloss:0.86698
# [162]	validation_0-mlogloss:0.86851
# [163]	validation_0-mlogloss:0.86874
# [164]	validation_0-mlogloss:0.86879
# [165]	validation_0-mlogloss:0.86876
# [166]	validation_0-mlogloss:0.86859
# [167]	validation_0-mlogloss:0.86766
# [168]	validation_0-mlogloss:0.86597
# [169]	validation_0-mlogloss:0.86701
# [170]	validation_0-mlogloss:0.86684
# [171]	validation_0-mlogloss:0.86705
# [172]	validation_0-mlogloss:0.86639
# [173]	validation_0-mlogloss:0.86705
# [174]	validation_0-mlogloss:0.86781
# [175]	validation_0-mlogloss:0.86701
# [176]	validation_0-mlogloss:0.86768
# [177]	validation_0-mlogloss:0.86742
# [178]	validation_0-mlogloss:0.86710
# [179]	validation_0-mlogloss:0.86655
# [180]	validation_0-mlogloss:0.86613
# [181]	validation_0-mlogloss:0.86712
# [182]	validation_0-mlogloss:0.86656
# [183]	validation_0-mlogloss:0.86661
# [184]	validation_0-mlogloss:0.86640
# [185]	validation_0-mlogloss:0.86614
# [186]	validation_0-mlogloss:0.86737
# [187]	validation_0-mlogloss:0.86826
# [188]	validation_0-mlogloss:0.86762
# [189]	validation_0-mlogloss:0.86761
# [190]	validation_0-mlogloss:0.86661
# [191]	validation_0-mlogloss:0.86680
# [192]	validation_0-mlogloss:0.86690
# [193]	validation_0-mlogloss:0.86703
# [194]	validation_0-mlogloss:0.86607
# [195]	validation_0-mlogloss:0.86662
# [196]	validation_0-mlogloss:0.86734
# [197]	validation_0-mlogloss:0.86832
# [198]	validation_0-mlogloss:0.86952
# [199]	validation_0-mlogloss:0.86986
# [200]	validation_0-mlogloss:0.86942
# [201]	validation_0-mlogloss:0.86959
# [202]	validation_0-mlogloss:0.87084
# [203]	validation_0-mlogloss:0.87045
# [204]	validation_0-mlogloss:0.87013
# [205]	validation_0-mlogloss:0.87101
# [206]	validation_0-mlogloss:0.87055
# [207]	validation_0-mlogloss:0.87004
# [208]	validation_0-mlogloss:0.87098
# [209]	validation_0-mlogloss:0.87255
# [210]	validation_0-mlogloss:0.87309
# [211]	validation_0-mlogloss:0.87219
# [212]	validation_0-mlogloss:0.87150
# [213]	validation_0-mlogloss:0.87193
# [214]	validation_0-mlogloss:0.87139
# [215]	validation_0-mlogloss:0.87175
# [216]	validation_0-mlogloss:0.87180
# [217]	validation_0-mlogloss:0.87165
# [218]	validation_0-mlogloss:0.87172
# [219]	validation_0-mlogloss:0.87094
# [220]	validation_0-mlogloss:0.87083
# [221]	validation_0-mlogloss:0.87112
# [222]	validation_0-mlogloss:0.87200
# [223]	validation_0-mlogloss:0.87300
# [224]	validation_0-mlogloss:0.87340
# [225]	validation_0-mlogloss:0.87404
# [226]	validation_0-mlogloss:0.87413
# [227]	validation_0-mlogloss:0.87441
# [228]	validation_0-mlogloss:0.87395
# [229]	validation_0-mlogloss:0.87393
# [230]	validation_0-mlogloss:0.87433
# [231]	validation_0-mlogloss:0.87442
# [232]	validation_0-mlogloss:0.87563
# [233]	validation_0-mlogloss:0.87637
# [234]	validation_0-mlogloss:0.87559
# [235]	validation_0-mlogloss:0.87492
# [236]	validation_0-mlogloss:0.87509
# [237]	validation_0-mlogloss:0.87577
# [238]	validation_0-mlogloss:0.87574
# [239]	validation_0-mlogloss:0.87614
# [240]	validation_0-mlogloss:0.87644
# [241]	validation_0-mlogloss:0.87623
# [242]	validation_0-mlogloss:0.87693
# [243]	validation_0-mlogloss:0.87647
# [244]	validation_0-mlogloss:0.87664
# [245]	validation_0-mlogloss:0.87705
# [246]	validation_0-mlogloss:0.87755
# [247]	validation_0-mlogloss:0.87860
# [248]	validation_0-mlogloss:0.87940
# [249]	validation_0-mlogloss:0.87906
# [250]	validation_0-mlogloss:0.87810
# [251]	validation_0-mlogloss:0.87853
# [252]	validation_0-mlogloss:0.87843
# [253]	validation_0-mlogloss:0.87846
# [254]	validation_0-mlogloss:0.87854
# [255]	validation_0-mlogloss:0.87923
# [256]	validation_0-mlogloss:0.87876
# [257]	validation_0-mlogloss:0.87787
# [258]	validation_0-mlogloss:0.87821
# [259]	validation_0-mlogloss:0.87854
# [260]	validation_0-mlogloss:0.87944
# [261]	validation_0-mlogloss:0.87899
# [262]	validation_0-mlogloss:0.87922
# [263]	validation_0-mlogloss:0.87978
# [264]	validation_0-mlogloss:0.88055
# [265]	validation_0-mlogloss:0.88025
# [266]	validation_0-mlogloss:0.88018
# [267]	validation_0-mlogloss:0.88039
# [268]	validation_0-mlogloss:0.88016
# [269]	validation_0-mlogloss:0.87984
# [270]	validation_0-mlogloss:0.88052
# [271]	validation_0-mlogloss:0.88132
# [272]	validation_0-mlogloss:0.88166
# [273]	validation_0-mlogloss:0.88158
# [274]	validation_0-mlogloss:0.88188
# [275]	validation_0-mlogloss:0.88207
# [276]	validation_0-mlogloss:0.88188
# [277]	validation_0-mlogloss:0.88222
# [278]	validation_0-mlogloss:0.88263
# [279]	validation_0-mlogloss:0.88318
# [280]	validation_0-mlogloss:0.88305
# [281]	validation_0-mlogloss:0.88310
# [282]	validation_0-mlogloss:0.88358
# [283]	validation_0-mlogloss:0.88416
# [284]	validation_0-mlogloss:0.88410
# [285]	validation_0-mlogloss:0.88400
# [286]	validation_0-mlogloss:0.88423
# [287]	validation_0-mlogloss:0.88344
# [288]	validation_0-mlogloss:0.88403
# [289]	validation_0-mlogloss:0.88466
# [290]	validation_0-mlogloss:0.88420
# [291]	validation_0-mlogloss:0.88381
# [292]	validation_0-mlogloss:0.88371
# [293]	validation_0-mlogloss:0.88414
# [294]	validation_0-mlogloss:0.88398
# [295]	validation_0-mlogloss:0.88415
# [296]	validation_0-mlogloss:0.88403
# [297]	validation_0-mlogloss:0.88429
# [298]	validation_0-mlogloss:0.88505
# [299]	validation_0-mlogloss:0.88538
# [300]	validation_0-mlogloss:0.88498
# [301]	validation_0-mlogloss:0.88486
# [302]	validation_0-mlogloss:0.88542
# [303]	validation_0-mlogloss:0.88561
# [304]	validation_0-mlogloss:0.88592
# [305]	validation_0-mlogloss:0.88588
# [306]	validation_0-mlogloss:0.88609
# [307]	validation_0-mlogloss:0.88690
# [308]	validation_0-mlogloss:0.88714
# [309]	validation_0-mlogloss:0.88690
# [310]	validation_0-mlogloss:0.88749
# [311]	validation_0-mlogloss:0.88763
# [312]	validation_0-mlogloss:0.88751
# [313]	validation_0-mlogloss:0.88736
# [314]	validation_0-mlogloss:0.88781
# [315]	validation_0-mlogloss:0.88799
# [316]	validation_0-mlogloss:0.88850
# [317]	validation_0-mlogloss:0.88854
# [318]	validation_0-mlogloss:0.88857
# [319]	validation_0-mlogloss:0.88851
# [320]	validation_0-mlogloss:0.88872
# [321]	validation_0-mlogloss:0.88875
# [322]	validation_0-mlogloss:0.88839
# [323]	validation_0-mlogloss:0.88809
# [324]	validation_0-mlogloss:0.88781
# [325]	validation_0-mlogloss:0.88793
# [326]	validation_0-mlogloss:0.88735
# [327]	validation_0-mlogloss:0.88722
# [328]	validation_0-mlogloss:0.88755
# [329]	validation_0-mlogloss:0.88755
# [330]	validation_0-mlogloss:0.88737
# [331]	validation_0-mlogloss:0.88839
# [332]	validation_0-mlogloss:0.88914
# [333]	validation_0-mlogloss:0.88993
# [334]	validation_0-mlogloss:0.88973
# [335]	validation_0-mlogloss:0.89025
# [336]	validation_0-mlogloss:0.89113
# [337]	validation_0-mlogloss:0.89138
# [338]	validation_0-mlogloss:0.89079
# [339]	validation_0-mlogloss:0.89120
# [340]	validation_0-mlogloss:0.89122
# [341]	validation_0-mlogloss:0.89101
# [342]	validation_0-mlogloss:0.89193
# [343]	validation_0-mlogloss:0.89224
# [344]	validation_0-mlogloss:0.89197
# [345]	validation_0-mlogloss:0.89126
# [346]	validation_0-mlogloss:0.89130
# [347]	validation_0-mlogloss:0.89148
# [348]	validation_0-mlogloss:0.89142
# [349]	validation_0-mlogloss:0.89151
# [350]	validation_0-mlogloss:0.89137
# [351]	validation_0-mlogloss:0.89082
# [352]	validation_0-mlogloss:0.89042
# [353]	validation_0-mlogloss:0.89048
# [354]	validation_0-mlogloss:0.89090
# [355]	validation_0-mlogloss:0.89092
# [356]	validation_0-mlogloss:0.89156
# [357]	validation_0-mlogloss:0.89222
# [358]	validation_0-mlogloss:0.89223
# [359]	validation_0-mlogloss:0.89186
# [360]	validation_0-mlogloss:0.89214
# [361]	validation_0-mlogloss:0.89234
# [362]	validation_0-mlogloss:0.89206
# [363]	validation_0-mlogloss:0.89286
# [364]	validation_0-mlogloss:0.89274
# [365]	validation_0-mlogloss:0.89260
# [366]	validation_0-mlogloss:0.89255
# [367]	validation_0-mlogloss:0.89315
# [368]	validation_0-mlogloss:0.89226
# [369]	validation_0-mlogloss:0.89201
# [370]	validation_0-mlogloss:0.89231
# [371]	validation_0-mlogloss:0.89210
# [372]	validation_0-mlogloss:0.89218
# [373]	validation_0-mlogloss:0.89299
# [374]	validation_0-mlogloss:0.89247
# [375]	validation_0-mlogloss:0.89225
# [376]	validation_0-mlogloss:0.89191
# [377]	validation_0-mlogloss:0.89225
# [378]	validation_0-mlogloss:0.89264
# [379]	validation_0-mlogloss:0.89237
# [380]	validation_0-mlogloss:0.89218
# [381]	validation_0-mlogloss:0.89204
# [382]	validation_0-mlogloss:0.89186
# [383]	validation_0-mlogloss:0.89195
# [384]	validation_0-mlogloss:0.89142
# [385]	validation_0-mlogloss:0.89127
# [386]	validation_0-mlogloss:0.89147
# [387]	validation_0-mlogloss:0.89158
# [388]	validation_0-mlogloss:0.89220
# [389]	validation_0-mlogloss:0.89276
# [390]	validation_0-mlogloss:0.89237
# [391]	validation_0-mlogloss:0.89228
# [392]	validation_0-mlogloss:0.89268
# [393]	validation_0-mlogloss:0.89246
# [394]	validation_0-mlogloss:0.89304
# [395]	validation_0-mlogloss:0.89364
# [396]	validation_0-mlogloss:0.89406
# [397]	validation_0-mlogloss:0.89404
# [398]	validation_0-mlogloss:0.89390
# [399]	validation_0-mlogloss:0.89452
# [400]	validation_0-mlogloss:0.89458
# [401]	validation_0-mlogloss:0.89542
# [402]	validation_0-mlogloss:0.89551
# [403]	validation_0-mlogloss:0.89554
# [404]	validation_0-mlogloss:0.89550
# [405]	validation_0-mlogloss:0.89565
# [406]	validation_0-mlogloss:0.89534
# [407]	validation_0-mlogloss:0.89511
# [408]	validation_0-mlogloss:0.89511
# [409]	validation_0-mlogloss:0.89559
# [410]	validation_0-mlogloss:0.89639
# [411]	validation_0-mlogloss:0.89648
# [412]	validation_0-mlogloss:0.89667
# [413]	validation_0-mlogloss:0.89646
# [414]	validation_0-mlogloss:0.89659
# [415]	validation_0-mlogloss:0.89633
# [416]	validation_0-mlogloss:0.89656
# [417]	validation_0-mlogloss:0.89745
# [418]	validation_0-mlogloss:0.89704
# [419]	validation_0-mlogloss:0.89686
# [420]	validation_0-mlogloss:0.89759
# [421]	validation_0-mlogloss:0.89797
# [422]	validation_0-mlogloss:0.89780
# [423]	validation_0-mlogloss:0.89806
# [424]	validation_0-mlogloss:0.89865
# [425]	validation_0-mlogloss:0.89824
# [426]	validation_0-mlogloss:0.89831
# [427]	validation_0-mlogloss:0.89858
# [428]	validation_0-mlogloss:0.89837
# [429]	validation_0-mlogloss:0.89850
# [430]	validation_0-mlogloss:0.89859
# [431]	validation_0-mlogloss:0.89863
# [432]	validation_0-mlogloss:0.89863
# [433]	validation_0-mlogloss:0.89884
# [434]	validation_0-mlogloss:0.89897
# [435]	validation_0-mlogloss:0.89935
# [436]	validation_0-mlogloss:0.89949
# [437]	validation_0-mlogloss:0.89911
# [438]	validation_0-mlogloss:0.89939
# [439]	validation_0-mlogloss:0.89954
# [440]	validation_0-mlogloss:0.89976
# [441]	validation_0-mlogloss:0.89941
# [442]	validation_0-mlogloss:0.89988
# [443]	validation_0-mlogloss:0.90011
# [444]	validation_0-mlogloss:0.89979
# [445]	validation_0-mlogloss:0.90018
# [446]	validation_0-mlogloss:0.90020
# [447]	validation_0-mlogloss:0.90016
# [448]	validation_0-mlogloss:0.90026
# [449]	validation_0-mlogloss:0.90049
# [450]	validation_0-mlogloss:0.90029
# [451]	validation_0-mlogloss:0.90044
# [452]	validation_0-mlogloss:0.90026
# [453]	validation_0-mlogloss:0.90013
# [454]	validation_0-mlogloss:0.90047
# [455]	validation_0-mlogloss:0.90101
# [456]	validation_0-mlogloss:0.90135
# [457]	validation_0-mlogloss:0.90175
# [458]	validation_0-mlogloss:0.90222
# [459]	validation_0-mlogloss:0.90240
# [460]	validation_0-mlogloss:0.90239
# [461]	validation_0-mlogloss:0.90255
# [462]	validation_0-mlogloss:0.90306
# [463]	validation_0-mlogloss:0.90286
# [464]	validation_0-mlogloss:0.90286
# [465]	validation_0-mlogloss:0.90312
# [466]	validation_0-mlogloss:0.90392
# [467]	validation_0-mlogloss:0.90419
# [468]	validation_0-mlogloss:0.90432
# [469]	validation_0-mlogloss:0.90405
# [470]	validation_0-mlogloss:0.90438
# [471]	validation_0-mlogloss:0.90440
# [472]	validation_0-mlogloss:0.90449
# [473]	validation_0-mlogloss:0.90384
# [474]	validation_0-mlogloss:0.90365
# [475]	validation_0-mlogloss:0.90403
# [476]	validation_0-mlogloss:0.90438
# [477]	validation_0-mlogloss:0.90451
# [478]	validation_0-mlogloss:0.90416
# [479]	validation_0-mlogloss:0.90454
# [480]	validation_0-mlogloss:0.90457
# [481]	validation_0-mlogloss:0.90516
# [482]	validation_0-mlogloss:0.90512
# [483]	validation_0-mlogloss:0.90484
# [484]	validation_0-mlogloss:0.90510
# [485]	validation_0-mlogloss:0.90516
# [486]	validation_0-mlogloss:0.90513
# [487]	validation_0-mlogloss:0.90545
# [488]	validation_0-mlogloss:0.90547
# [489]	validation_0-mlogloss:0.90565
# [490]	validation_0-mlogloss:0.90570
# [491]	validation_0-mlogloss:0.90591
# [492]	validation_0-mlogloss:0.90580
# [493]	validation_0-mlogloss:0.90619
# [494]	validation_0-mlogloss:0.90605
# [495]	validation_0-mlogloss:0.90590
# [496]	validation_0-mlogloss:0.90596
# [497]	validation_0-mlogloss:0.90586
# [498]	validation_0-mlogloss:0.90577
# [499]	validation_0-mlogloss:0.90594

# %%
y_pred_mi = model_xgb.predict(X_test_mi)

model_report("PCA + MLP", y_test, y_pred_mi)
# Out:
# ============================================================
# 📊 MODEL REPORT: PCA + MLP
# ============================================================
#
# 🔹 Accuracy:
# 0.5734265734265734
#
# 🔹 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.58      0.75      0.66        57
#            1       0.63      0.65      0.64        48
#            2       0.40      0.21      0.28        38
#
#     accuracy                           0.57       143
#    macro avg       0.54      0.54      0.52       143
# weighted avg       0.55      0.57      0.55       143
#
#
# 🔹 Confusion Matrix:
# [[43  8  6]
#  [11 31  6]
#  [20 10  8]]

# %% [markdown]
# # XAI

# %%
X_latent = encoder.predict(X_filtered)

# %%
import shap

explainer = shap.Explainer(model.predict, X_train)

shap_values = explainer(X_test)

# %%
import umap.umap_ as umap

reducer = umap.UMAP()

embedding = reducer.fit_transform(X_latent)
