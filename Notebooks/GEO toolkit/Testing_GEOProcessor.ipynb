# %%
# !pip install GEOparse

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/Personal/brain_disease_prediction/GEO/GEO toolkit')

# %%
from geo_processor import GEOProcessor
import pandas as pd
import numpy as np

# %%
file_path = "/content/drive/MyDrive/Colab Notebooks/Personal/brain_disease_prediction/GEO/Alzheimer/GSE5281/GSE5281_family.soft.gz"

gse = GEOProcessor(file_path)

# %%
gse.load_data()
# Out:
# 30-Apr-2026 09:40:20 INFO GEOparse - Parsing /content/drive/MyDrive/Colab Notebooks/Personal/brain_disease_prediction/GEO/Alzheimer/GSE5281/GSE5281_family.soft.gz:
# INFO:GEOparse:Parsing /content/drive/MyDrive/Colab Notebooks/Personal/brain_disease_prediction/GEO/Alzheimer/GSE5281/GSE5281_family.soft.gz:
# 30-Apr-2026 09:40:20 DEBUG GEOparse - DATABASE: GeoMiame
# DEBUG:GEOparse:DATABASE: GeoMiame
# 30-Apr-2026 09:40:20 DEBUG GEOparse - SERIES: GSE5281
# DEBUG:GEOparse:SERIES: GSE5281
# 30-Apr-2026 09:40:20 DEBUG GEOparse - PLATFORM: GPL570
# DEBUG:GEOparse:PLATFORM: GPL570
# /usr/local/lib/python3.12/dist-packages/GEOparse/GEOparse.py:401: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   return read_csv(StringIO(data), index_col=None, sep="\t")
# 30-Apr-2026 09:40:27 DEBUG GEOparse - SAMPLE: GSM119615
# DEBUG:GEOparse:SAMPLE: GSM119615
# 30-Apr-2026 09:40:28 DEBUG GEOparse - SAMPLE: GSM119616
# DEBUG:GEOparse:SAMPLE: GSM119616
# ...

# %%
gse.show_info()
# Out:
# The GSE5281 dataset contains 161 patients
# Title: Alzheimer's disease and the normal aged brain (steph-affy-human-433773)
# Summary: Information about the genes that are preferentially expressed during the course of Alzheimer’s disease (AD) could improve our understanding of the molecular mechanisms involved in the pathogenesis of this common cause of cognitive impairment in older persons, provide new opportunities in the diagnosis, early detection, and tracking of this disorder, and provide novel targets for the discovery of interventions to treat and prevent this disorder. Information about the genes that are preferentially expressed in relationship to normal neurological aging could provide new information about the molecular mechanisms that are involved in normal age-related cognitive decline and a host of age-related neurological disorders, and they could provide novel targets for the discovery of interventions to mitigate some of these deleterious effects.

# %%
print(gse.get_patient_ids())
# Out:
# ['GSM119615', 'GSM119616', 'GSM119617', 'GSM119618', 'GSM119619', 'GSM119620', 'GSM119621', 'GSM119622', 'GSM119623', 'GSM119624', 'GSM119625', 'GSM119626', 'GSM119627', 'GSM119628', 'GSM119629', 'GSM119630', 'GSM119631', 'GSM119632', 'GSM119633', 'GSM119634', 'GSM119635', 'GSM119636', 'GSM119637', 'GSM119638', 'GSM119639', 'GSM119640', 'GSM119641', 'GSM119642', 'GSM119643', 'GSM119644', 'GSM119645', 'GSM119646', 'GSM119647', 'GSM119648', 'GSM119649', 'GSM119650', 'GSM119651', 'GSM119652', 'GSM119653', 'GSM119654', 'GSM119655', 'GSM119656', 'GSM119657', 'GSM119658', 'GSM119659', 'GSM119660', 'GSM119661', 'GSM119662', 'GSM119663', 'GSM119664', 'GSM119665', 'GSM119666', 'GSM119667', 'GSM119668', 'GSM119669', 'GSM119670', 'GSM119671', 'GSM119672', 'GSM119673', 'GSM119674', 'GSM119675', 'GSM119676', 'GSM119677', 'GSM119678', 'GSM119679', 'GSM119680', 'GSM119681', 'GSM119682', 'GSM119683', 'GSM119684', 'GSM119685', 'GSM119686', 'GSM119687', 'GSM119688', 'GSM238763', 'GSM238790', 'GSM23879
# ...

# %%
gse.show_patient_data("GSM119615")
# Out:
# Patient ID:
# GSM119615
#
# Patient gene data:
#                ID_REF       VALUE ABS_CALL  DETECTION P-VALUE
# 0      AFFX-BioB-5_at  276.480650        P           0.000754
# 1      AFFX-BioB-M_at  391.856960        P           0.000169
# 2      AFFX-BioB-3_at  269.120820        P           0.000095
# 3      AFFX-BioC-5_at  852.272400        P           0.000095
# 4      AFFX-BioC-3_at  821.932430        P           0.000044
# ...               ...         ...      ...                ...
# 54670      1570644_at   45.333084        A           0.274170
# 54671      1570645_at    8.507533        A           0.239258
# 54672      1570650_at   40.956710        A           0.398926
# 54673      1570651_at   31.751217        A           0.633789
# 54674      1570653_at   13.508081        A           0.725830
#
# [54675 rows x 4 columns]
#
# Patient metadata:
# ...

# %%
gse.show_patient_metadata("GSM119615")
# Out:
# title: ['EC control 1']
# geo_accession: ['GSM119615']
# status: ['Public on Jul 10 2006']
# submission_date: ['Jul 10 2006']
# last_update_date: ['Jun 26 2019']
# type: ['RNA']
# channel_count: ['1']
# source_name_ch1: ['brain, Entorhinal Cortex']
# organism_ch1: ['Homo sapiens']
# taxid_ch1: ['9606']
# characteristics_ch1: ['Sample Amount: 10 ug', 'Bio-Source Name: EC control 1', 'Organism: Human', 'Organ/Tissue Type: brain', 'Organ Region: Entorhinal Cortex', 'Cell Type: layer III neurons', 'Ethnicity: Caucasian', 'Developmental Stage: Adult', 'Disease State: normal', 'Sex: male', 'Genetic Variation: None', 'Age: 63 years']
# molecule_ch1: ['total RNA']
# description: ['arrayconsortium.tgen.org::biosample.433887', 'AD control']
# platform_id: ['GPL570']
# contact_name: ['Winnie,,Liang']
# contact_email: ['wliang@tgen.org']
# contact_institute: ['Translational Genomics']
# contact_address: ['445 N. Fifth Street']
# contact_city: ['Phoenix']
# contact_state: ['AZ']
# ...

# %%
print(gse.get_table_columns())
# Out:
# ['ID_REF', 'VALUE', 'ABS_CALL', 'DETECTION P-VALUE']

# %%
dfs = gse.build_data_frames()

# %%
dfs["value"]
# Out:
#                  GSM119615   GSM119616    GSM119617    GSM119618    GSM119619  \
# ID_REF
# AFFX-BioB-5_at  276.480650  173.886460   340.415950   462.013850   969.227840
# AFFX-BioB-M_at  391.856960  248.449940   395.968800   605.429000  1353.379600
# AFFX-BioB-3_at  269.120820  129.086730   256.594270   268.400400   846.799600
# AFFX-BioC-5_at  852.272400  581.811700  1096.706300  1461.096700  2789.578100
# AFFX-BioC-3_at  821.932430  849.975160  1438.471000  1698.329700  3443.694600
# ...                    ...         ...          ...          ...          ...
# 1570644_at       45.333084   39.368587    91.836380    18.226810    90.429170
# 1570645_at        8.507533    2.387396    11.159609     8.078927     2.897786
# 1570650_at       40.956710   40.124730    80.728134    76.397285    51.699700
# 1570651_at       31.751217   32.498660    92.726260    94.155716    64.194610
# 1570653_at       13.508081   20.270626    77.864815     7.936954    58.996044
#
# ...

# %%
gse.get_patient_labels("GSM119615")
# Out:
# Patient: GSM119615
# Sample Amount: 10 ug
# Bio-Source Name: EC control 1
# Organism: Human
# Organ/Tissue Type: brain
# Organ Region: Entorhinal Cortex
# Cell Type: layer III neurons
# Ethnicity: Caucasian
# Developmental Stage: Adult
# Disease State: normal
# Sex: male
# Genetic Variation: None
# Age: 63 years
# ('GSM119615',
#  ['Sample Amount: 10 ug',
#   'Bio-Source Name: EC control 1',
#   'Organism: Human',
#   'Organ/Tissue Type: brain',
#   'Organ Region: Entorhinal Cortex',
#   'Cell Type: layer III neurons',
#   'Ethnicity: Caucasian',
#   'Developmental Stage: Adult',
#   'Disease State: normal',
#   'Sex: male',
#   'Genetic Variation: None',
#   'Age: 63 years'])

# %%
gse.build_gse_metadata()
# Out:
#     patient_id sample amount  bio-source name organism organ/tissue type  \
# 0    GSM119615         10 ug     EC control 1    Human             brain
# 1    GSM119616         10 ug     EC control 2    Human             brain
# 2    GSM119617         10 ug     EC control 3    Human             brain
# 3    GSM119618         10 ug     EC control 4    Human             brain
# 4    GSM119619         10 ug     EC control 5    Human             brain
# ..         ...           ...              ...      ...               ...
# 156  GSM238951         10 ng  VCX_affected_15    Human             brain
# 157  GSM238952         10 ng  VCX_affected_16    Human             brain
# 158  GSM238953         10 ng  VCX_affected_17    Human             brain
# 159  GSM238955         10 ng  VCX_affected_18    Human             brain
# 160  GSM238963         10 ng  VCX_affected_19    Human             brain
#
#               organ region          cell type  ethnicity developmental stage  \
# ...
